# %%
tech_platform = "Azure Databricks"
print(f"Welcome to this {tech_platform} course!")
# Out:
# Welcome to this Azure Databricks course!

# %%
# %sql
select "Welcome to this Databricks Course!!!"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>"Welcome to this Databricks Course!!!"</th></tr></thead><tbody><tr><td>Welcome to this Databricks Course!!!</td></tr></tbody></table></div>

# %%
# abc

# %% [markdown]
# # This is a header

# %% [markdown]
# ## This is a sub-header
